# %% [markdown]
# <a href="https://colab.research.google.com/github/KHarikaReddy/Shiva/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from wordcloud import WordCloud

# %%
pd.read_csv("ar_properties.csv")
# Out:
#                              id    ad_type  start_date    end_date  \
# 0      wdQ5hWhv8P14T7Sh9g4QCg==  Propiedad  2020-12-25  9999-12-31
# 1      nnMBYZ4RMRY+vm753EtA+g==  Propiedad  2020-12-25  9999-12-31
# 2      +dnVA1K6JxzL1zAjOEQ1pA==  Propiedad  2020-12-25  2020-12-29
# 3      dLHXKN5/sRZpm9Yk0yI2nA==  Propiedad  2020-12-25  2020-12-29
# 4      wtw/k887EPipd37UYHKb1Q==  Propiedad  2020-12-25  9999-12-31
# ...                         ...        ...         ...         ...
# 72943  YczcfaDGQIUbVHR16/9RNw==  Propiedad  2020-10-10  2020-10-10
# 72944  uhmrqGNpKYK8GIsKchC2Nw==  Propiedad  2020-10-10  2020-12-02
# 72945  RVDiEBmzgyZygkRcTe0CUg==  Propiedad  2020-10-10  2020-10-10
# 72946  saWcpMmJseTJ4u50um3rPg==  Propiedad  2020-10-10  9999-12-31
# 72947  szKOC6Sy6R2DNj4cBSr7GA==  Propiedad  2020-10-10  2020-10-10
#
#        created_on        lat        lon         l1                        l2  \
# 0      2020-12-25 -32.716652 -68.642692  Argentina                   Mendoza
# ...

# %%
data  = pd.read_csv("ar_properties.csv")

# %%
data.shape
# Out:
# (72948, 25)

# %%
data.tail()
# Out:
#                              id    ad_type  start_date    end_date  \
# 72943  YczcfaDGQIUbVHR16/9RNw==  Propiedad  2020-10-10  2020-10-10
# 72944  uhmrqGNpKYK8GIsKchC2Nw==  Propiedad  2020-10-10  2020-12-02
# 72945  RVDiEBmzgyZygkRcTe0CUg==  Propiedad  2020-10-10  2020-10-10
# 72946  saWcpMmJseTJ4u50um3rPg==  Propiedad  2020-10-10  9999-12-31
# 72947  szKOC6Sy6R2DNj4cBSr7GA==  Propiedad  2020-10-10  2020-10-10
#
#        created_on        lat        lon         l1                      l2  \
# 72943  2020-10-10 -34.807812 -58.407208  Argentina  Bs.As. G.B.A. Zona Sur
# 72944  2020-10-10 -34.767158 -58.410192  Argentina  Bs.As. G.B.A. Zona Sur
# 72945  2020-10-10 -34.752187 -58.408434  Argentina  Bs.As. G.B.A. Zona Sur
# 72946  2020-10-10 -34.769499 -58.385292  Argentina  Bs.As. G.B.A. Zona Sur
# 72947  2020-10-10 -34.756028 -58.429669  Argentina  Bs.As. G.B.A. Zona Sur
#
#                     l3  ... bathrooms surface_total  surface_covered  \
# ...

# %%
data.head()
# Out:
#                          id    ad_type  start_date    end_date  created_on  \
# 0  wdQ5hWhv8P14T7Sh9g4QCg==  Propiedad  2020-12-25  9999-12-31  2020-12-25
# 1  nnMBYZ4RMRY+vm753EtA+g==  Propiedad  2020-12-25  9999-12-31  2020-12-25
# 2  +dnVA1K6JxzL1zAjOEQ1pA==  Propiedad  2020-12-25  2020-12-29  2020-12-25
# 3  dLHXKN5/sRZpm9Yk0yI2nA==  Propiedad  2020-12-25  2020-12-29  2020-12-25
# 4  wtw/k887EPipd37UYHKb1Q==  Propiedad  2020-12-25  9999-12-31  2020-12-25
#
#          lat        lon         l1                        l2        l3  ...  \
# 0 -32.716652 -68.642692  Argentina                   Mendoza       NaN  ...
# 1 -24.797723 -65.467514  Argentina                     Salta       NaN  ...
# 2 -34.919373 -58.020591  Argentina    Bs.As. G.B.A. Zona Sur  La Plata  ...
# 3 -34.919455 -58.024807  Argentina    Bs.As. G.B.A. Zona Sur  La Plata  ...
# 4 -34.364924 -58.783143  Argentina  Bs.As. G.B.A. Zona Norte   Escobar  ...
#
# ...

# %%
data.created_on.unique()
# Out:
# array(['2020-12-25', '2020-12-26', '2021-01-01', '2020-10-12',
#        '2020-08-09', '2020-11-15', '2020-06-07', '2020-08-22',
#        '2020-06-15', '2020-06-08', '2020-02-06', '2020-08-02',
#        '2020-02-01', '2020-06-23', '2020-07-04', '2020-05-25',
#        '2020-05-11', '2020-08-11', '2020-11-27', '2019-12-29',
#        '2020-05-23', '2020-07-19', '2020-11-02', '2020-07-24',
#        '2020-05-05', '2020-07-10', '2020-05-09', '2020-10-17',
#        '2020-06-19', '2020-06-04', '2020-07-12', '2020-09-19',
#        '2019-12-31', '2021-01-11', '2020-11-16', '2020-07-22',
#        '2020-05-13', '2021-01-02', '2020-08-15', '2020-09-13',
#        '2020-10-10'], dtype=object)

# %%
data.created_on.nunique()
# Out:
# 41

# %%
data[data['created_on'] == "2021-01-02"]
# Out:
#                              id    ad_type  start_date    end_date  \
# 66949  h7ZRbA/qlmoBg8EpIW9QFQ==  Propiedad  2021-01-02  9999-12-31
# 66950  tQanDoaGOV2IjPfGm+afnw==  Propiedad  2021-01-02  9999-12-31
# 66951  Yu8j5dphUyk/CAMl9MwQJQ==  Propiedad  2021-01-02  9999-12-31
# 66952  twRRg0k7jvueRCjy1xwumw==  Propiedad  2021-01-02  2021-01-11
# 66953  J8CNuZLxTEcRdj5u6STc7Q==  Propiedad  2021-01-02  9999-12-31
# ...                         ...        ...         ...         ...
# 67372  BviPQpGmCv8cX3Ps5uk4PQ==  Propiedad  2021-01-02  9999-12-31
# 67373  Rq2AI50arVn1XfRE5v9iMg==  Propiedad  2021-01-02  2021-01-12
# 67374  y33E4a+Xjb4h13iZiU4Qnw==  Propiedad  2021-01-02  2021-02-17
# 67375  I1kgE0mOB5JW1nnxtMOMGQ==  Propiedad  2021-01-02  9999-12-31
# 67376  RFWlxetQk7FWBqNE6tQVVQ==  Propiedad  2021-01-02  9999-12-31
#
#        created_on        lat        lon              l1  \
# 66949  2021-01-02 -27.604033 -56.682288       Argentina
# ...

# %%
data[data['created_on'] == "2020-07-19"]
# Out:
#                              id    ad_type  start_date    end_date  \
# 31349  A3tIbw6fv5xj0EpBQsAhPw==  Propiedad  2020-07-19  2020-09-02
# 31350  3jdEsfKw+uQHoRH/Wz/tMQ==  Propiedad  2020-07-19  2020-08-28
# 31351  n0WLMQrqpH0PVHW7YoroQQ==  Propiedad  2020-07-19  9999-12-31
# 31352  OsVbNYLE0rAAvdZiq2Nhfg==  Propiedad  2020-07-19  9999-12-31
# 31353  GLUpXo0cA1ZxcfE1qsvGrw==  Propiedad  2020-07-19  9999-12-31
# ...                         ...        ...         ...         ...
# 32629  hyZvBKFW0O6ybDS6zOrNqw==  Propiedad  2020-07-19  2020-07-22
# 32630  C/9CGBYr0CrRKlNd4K8Gew==  Propiedad  2020-07-19  2020-07-21
# 32631  zabOR0Yg1sBt9YKQc28/GQ==  Propiedad  2020-07-19  2020-08-03
# 32632  Eza7xlpsrfOZt8lb/biiGw==  Propiedad  2020-07-19  2020-09-02
# 32633  cBwaf2j9Nju7jDfGqL6RIw==  Propiedad  2020-07-19  9999-12-31
#
#        created_on        lat        lon         l1  \
# 31349  2020-07-19 -32.355373 -65.014252  Argentina
# 31350  2020-07-19 -24.782127 -65.423195  Argentina
# ...

# %%
data.shape
# Out:
# (72948, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72948 entries, 0 to 72947
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               72948 non-null  object
#  1   ad_type          72948 non-null  object
#  2   start_date       72948 non-null  object
#  3   end_date         72948 non-null  object
#  4   created_on       72948 non-null  object
#  5   lat              64016 non-null  float64
#  6   lon              63999 non-null  float64
#  7   l1               72948 non-null  object
#  8   l2               72948 non-null  object
#  9   l3               70653 non-null  object
#  10  l4               20467 non-null  object
#  11  l5               390 non-null    object
#  12  l6               0 non-null      float64
#  13  rooms            49878 non-null  float64
#  14  bedrooms         45174 non-null  float64
#  15  bathrooms        56657 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 lat           lon   l6         rooms      bedrooms  \
# count  64016.000000  63999.000000  0.0  49878.000000  45174.000000
# mean     -34.496420    -59.316098  NaN      2.852861      2.067340
# std        3.413395      2.736141  NaN      1.661859      1.791671
# min      -54.817930    -95.712891  NaN      1.000000     -1.000000
# 25%      -34.764646    -58.736539  NaN      2.000000      1.000000
# 50%      -34.601864    -58.455844  NaN      3.000000      2.000000
# 75%      -34.471879    -58.390092  NaN      4.000000      3.000000
# max       42.447929    -35.045025  NaN     40.000000    153.000000
#
#           bathrooms  surface_total  surface_covered         price
# count  56657.000000   39782.000000     3.861500e+04  6.932300e+04
# mean       1.686394     517.622694     9.317500e+02  3.252306e+05
# std        1.069805    4835.148739     1.010257e+05  1.556585e+06
# min        1.000000      10.000000    -1.300000e+02  0.000000e+00
# ...

# %%
data.drop_duplicates(['lat'],keep = 'first', inplace = True)

# %%
data.shape
# Out:
# (43062, 25)

# %%
data.isnull()
# Out:
#           id  ad_type  start_date  end_date  created_on    lat    lon     l1  \
# 0      False    False       False     False       False  False  False  False
# 1      False    False       False     False       False  False  False  False
# 2      False    False       False     False       False  False  False  False
# 3      False    False       False     False       False  False  False  False
# 4      False    False       False     False       False  False  False  False
# ...      ...      ...         ...       ...         ...    ...    ...    ...
# 72943  False    False       False     False       False  False  False  False
# 72944  False    False       False     False       False  False  False  False
# 72945  False    False       False     False       False  False  False  False
# 72946  False    False       False     False       False  False  False  False
# 72947  False    False       False     False       False  False  False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# id                     0
# ad_type                0
# start_date             0
# end_date               0
# created_on             0
# lat                    1
# lon                   18
# l1                     0
# l2                     0
# l3                  1112
# l4                 30771
# l5                 42872
# l6                 43062
# rooms              12439
# bedrooms           16234
# bathrooms           9134
# surface_total      18854
# surface_covered    19380
# price               2368
# currency            2512
# price_period       26240
# title                  1
# description            2
# property_type          1
# operation_type         1
# dtype: int64

# %%
data['l1']
# Out:
# 0        Argentina
# 1        Argentina
# 2        Argentina
# 3        Argentina
# 4        Argentina
#            ...
# 72943    Argentina
# 72944    Argentina
# 72945    Argentina
# 72946    Argentina
# 72947    Argentina
# Name: l1, Length: 43062, dtype: object

# %%
data['l1'].unique()
# Out:
# array(['Argentina', 'Uruguay', 'Estados Unidos', 'Brasil'], dtype=object)

# %%
data['l1'].nunique()
# Out:
# 4

# %%
print(data['l1'].unique()[0])
# Out:
# Argentina

# %%
type(data['l1'].unique()[0])
# Out:
# str

# %%
data['l1'] = data['l1'].apply(lambda x:x[2:-2])
print(data['l1'].unique())
# Out:
# ['genti' 'ugu' 'tados Unid' 'as']

# %%
data['l1'] = data['l1'].apply(lambda x: np.where(x == "","NA",x))
print(data['l1'].unique())
# Out:
# ['genti' 'ugu' 'tados Unid' 'as']

# %%
data['start_date'].unique()
# Out:
# array(['2020-12-25', '2020-12-26', '2021-01-01', '2020-10-12',
#        '2020-08-09', '2020-11-15', '2020-06-07', '2020-08-22',
#        '2020-06-15', '2020-06-08', '2020-02-06', '2020-08-02',
#        '2020-02-01', '2020-06-23', '2020-07-04', '2020-05-25',
#        '2020-05-11', '2020-08-11', '2020-11-27', '2019-12-29',
#        '2020-05-23', '2020-07-19', '2020-11-02', '2020-07-24',
#        '2020-05-05', '2020-07-10', '2020-05-09', '2020-10-17',
#        '2020-06-19', '2020-06-04', '2020-07-12', '2020-09-19',
#        '2019-12-31', '2021-01-11', '2020-11-16', '2020-07-22',
#        '2020-05-13', '2021-01-02', '2020-08-15', '2020-09-13',
#        '2020-10-10'], dtype=object)

# %%
len(data['start_date'].unique())
# Out:
# 41

# %%
data[data['start_date'] ==  "2021-01-02"]
# Out:
#                              id    ad_type  start_date    end_date  \
# 66949  h7ZRbA/qlmoBg8EpIW9QFQ==  Propiedad  2021-01-02  9999-12-31
# 66950  tQanDoaGOV2IjPfGm+afnw==  Propiedad  2021-01-02  9999-12-31
# 66953  J8CNuZLxTEcRdj5u6STc7Q==  Propiedad  2021-01-02  9999-12-31
# 66955  Ut72F7fuGeLVzK70lu+FBA==  Propiedad  2021-01-02  9999-12-31
# 66956  1ZImxpeGuBdJq/V2f3sNkg==  Propiedad  2021-01-02  9999-12-31
# ...                         ...        ...         ...         ...
# 67364  J/drIgkK12uTYRcV2Or5qA==  Propiedad  2021-01-02  2021-01-02
# 67365  4yBuFclV3EJQKETIlFYDiA==  Propiedad  2021-01-02  2021-03-01
# 67369  ckgF+2usDhfKYtsC200Snw==  Propiedad  2021-01-02  9999-12-31
# 67371  cg+dAzIfKIMCBaxgC/kYvw==  Propiedad  2021-01-02  2021-02-06
# 67373  Rq2AI50arVn1XfRE5v9iMg==  Propiedad  2021-01-02  2021-01-12
#
#        created_on        lat        lon          l1  \
# 66949  2021-01-02 -27.604033 -56.682288       genti
# 66950  2021-01-02 -34.030139 -53.564350         ugu
# ...

# %%
data['ad_type'].head()
# Out:
# 0    Propiedad
# 1    Propiedad
# 2    Propiedad
# 3    Propiedad
# 4    Propiedad
# Name: ad_type, dtype: object

# %%
data['ad_type'].unique()
# Out:
# array(['Propiedad'], dtype=object)

# %%
data['ad_type'].nunique()
# Out:
# 1

# %%
data['l2'].unique()
# Out:
# array(['Mendoza', 'Salta', 'Bs.As. G.B.A. Zona Sur',
#        'Bs.As. G.B.A. Zona Norte', 'Capital Federal',
#        'Buenos Aires Interior', 'Córdoba', 'Santa Fe',
#        'Buenos Aires Costa Atlántica', 'Neuquén', 'Río Negro',
#        'Bs.As. G.B.A. Zona Oeste', 'Tucumán', 'Corrientes', 'Maldonado',
#        'Chubut', 'Canelones', 'Florida', 'Montevideo', 'Chaco',
#        'La Pampa', 'Colonia', 'San Juan', 'San Luis', 'Entre Ríos',
#        'Misiones', 'Santa Cruz', 'Santiago Del Estero', 'Michigan',
#        'Miami', 'Jujuy', 'Tierra Del Fuego', 'Formosa', 'Catamarca',
#        'Rocha', 'Rio Grande do Norte', 'Rio de Janeiro', 'La Rioja',
#        'Santa Catarina', 'Maryland', 'Pennsylvania', 'São Paulo'],
#       dtype=object)

# %%
data['id'].head()
# Out:
# 0    wdQ5hWhv8P14T7Sh9g4QCg==
# 1    nnMBYZ4RMRY+vm753EtA+g==
# 2    +dnVA1K6JxzL1zAjOEQ1pA==
# 3    dLHXKN5/sRZpm9Yk0yI2nA==
# 4    wtw/k887EPipd37UYHKb1Q==
# Name: id, dtype: object

# %%
data['id'].tail()
# Out:
# 72943    YczcfaDGQIUbVHR16/9RNw==
# 72944    uhmrqGNpKYK8GIsKchC2Nw==
# 72945    RVDiEBmzgyZygkRcTe0CUg==
# 72946    saWcpMmJseTJ4u50um3rPg==
# 72947    szKOC6Sy6R2DNj4cBSr7GA==
# Name: id, dtype: object

# %%
data['id'].nunique()
# Out:
# 43062

# %%
data['lon']
# Out:
# 0       -68.642692
# 1       -65.467514
# 2       -58.020591
# 3       -58.024807
# 4       -58.783143
#            ...
# 72943   -58.407208
# 72944   -58.410192
# 72945   -58.408434
# 72946   -58.385292
# 72947   -58.429669
# Name: lon, Length: 43062, dtype: float64

# %%
data['end_date'].unique()
# Out:
# array(['9999-12-31', '2020-12-29', '2020-12-30', '2021-03-05',
#        '2021-01-31', '2021-01-07', '2020-12-26', '2021-01-09',
#        '2021-02-13', '2021-01-02', '2021-01-05', '2021-01-04',
#        '2021-01-08', '2020-12-25', '2021-01-01', '2021-02-10',
#        '2021-01-14', '2021-01-06', '2021-01-12', '2021-02-09',
#        '2021-01-03', '2021-01-10', '2021-01-26', '2021-03-10',
#        '2020-12-28', '2020-12-27', '2021-02-14', '2021-01-13',
#        '2021-01-11', '2021-02-27', '2021-02-20', '2021-02-18',
#        '2021-01-25', '2021-02-03', '2021-03-08', '2021-02-26',
#        '2021-02-11', '2021-01-18', '2021-02-25', '2021-01-20',
#        '2021-01-15', '2021-01-29', '2021-03-06', '2021-02-15',
#        '2021-01-27', '2021-02-04', '2021-03-02', '2021-01-19',
#        '2021-01-17', '2021-02-01', '2021-03-01', '2021-02-05',
#        '2021-02-06', '2021-01-24', '2021-02-02', '2021-02-17',
#        '2021-03-04', '2021-03-14', '2021-02-23', '2021-01-16',
# ...

# %%
data['end_date'].nunique()
# Out:
# 431

# %%
data['end_date'] = data['end_date'].fillna("No end_date")

# %%
data['end_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
end_date = []
data['end_date'].apply(lambda x:end_date.extend(x.split(",")))
end_date = pd.Series(end_date)
print("Total unique end_date =  ", end_date.nunique())
# Out:
# Total unique end_date =   431

# %%
data['end_date']
# Out:
# 0        9999-12-31
# 1        9999-12-31
# 2        2020-12-29
# 3        2020-12-29
# 4        9999-12-31
#             ...
# 72943    2020-10-10
# 72944    2020-12-02
# 72945    2020-10-10
# 72946    9999-12-31
# 72947    2020-10-10
# Name: end_date, Length: 43062, dtype: object

# %%
data['l3']
# Out:
# 0                    NaN
# 1                    NaN
# 2               La Plata
# 3               La Plata
# 4                Escobar
#               ...
# 72943    Almirante Brown
# 72944    Lomas de Zamora
# 72945    Lomas de Zamora
# 72946    Lomas de Zamora
# 72947    Lomas de Zamora
# Name: l3, Length: 43062, dtype: object

# %%
data['l3'].unique()
# Out:
# array([nan, 'La Plata', 'Escobar', 'San Nicolás', 'Salta', 'Palermo',
#        'Tandil', 'Córdoba', 'Santa Fe', 'Villa Carlos Paz',
#        'Villa Ciudad de América', 'Monte Hermoso', 'Villa Pehuenia',
#        'Pinamar', 'Alta Gracia', 'Villa Gesell', 'Mar del Plata',
#        'Belgrano', 'San Carlos de Bariloche', 'Confluencia',
#        'San Cristobal', 'Centro / Microcentro', 'Recoleta', 'Villa Luro',
#        'Barrio Norte', 'Exaltación de la Cruz', 'Quilmes', 'Mina Clavero',
#        'Tigre', 'Flores', 'Saavedra', 'Caballito', 'Colegiales',
#        'Pompeya', 'Lácar', 'Morón', 'Iriondo', 'Rosario', 'Hurlingham',
#        'San Vicente', 'Villa Parque Siquiman', 'San Clemente del Tuyú',
#        'Punilla', 'San Rafael', 'Tres de Febrero', 'Monserrat',
#        'Cipolletti', 'El Chocón', 'Balvanera', 'Villa Urquiza',
#        'Esteban Echeverría', 'Boedo', 'Nuñez', 'Coghlan', 'Liniers',
#        'Ituzaingó', 'Villa Devoto', 'Puerto Madero', 'Lomas de Zamora',
# ...

# %%
data['l3'].nunique()
# Out:
# 589

# %%
data['rooms'].nunique()
# Out:
# 25

# %%
properties = data['property_type'].value_counts()

# %%
properties
# Out:
# property_type
# Departamento       20294
# Casa               10331
# Lote                3905
# PH                  2338
# Local comercial     2226
# Otro                1631
# Oficina             1290
# Cochera              472
# Depósito             436
# Casa de campo        138
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (43062, 25)

# %%
print("total properties in our data = ", data.shape[0])
# Out:
# total properties in our data =  43062

# %%
top10_properties = data['property_type'].value_counts()[:10].sort_values(ascending = True)

# %%
top10_properties
# Out:
# property_type
# Casa de campo        138
# Depósito             436
# Cochera              472
# Oficina             1290
# Otro                1631
# Local comercial     2226
# PH                  2338
# Lote                3905
# Casa               10331
# Departamento       20294
# Name: count, dtype: int64

# %%
height = top10_properties.values
bars = top10_properties.index
y_pos = np.arange(len(bars))

fig = plt.figure(figsize = [11,8], frameon = False)
ax = fig.gca()
ax.spines['top'].set_visible("#424242")
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color("#424242")
ax.spines['bottom'].set_color("#424242")

colors = ['#f9cdac', '#f2a49f', '#ec7c92', '#e65586','#bc438b', '#933291','#692398','#551c7b','#41155e','#2d0f41']

plt.barh(y_pos, height, color = colors)

plt.xticks(color = "#424242")
plt.yticks(y_pos, bars, color = "#424242")
plt.xlabel("Number of properties")

for i, v in enumerate(height):
    plt.text(v + 3, i, str(v), color = 'black', fontweight = 'bold')
plt.title("Top 10 properties")
plt.show()

# %%
properties = data['property_type'].value_counts()

# %%
properties
# Out:
# property_type
# Departamento       20294
# Casa               10331
# Lote                3905
# PH                  2338
# Local comercial     2226
# Otro                1631
# Oficina             1290
# Cochera              472
# Depósito             436
# Casa de campo        138
# Name: count, dtype: int64

# %%
data['l1']
# Out:
# 0        genti
# 1        genti
# 2        genti
# 3        genti
# 4        genti
#          ...
# 72943    genti
# 72944    genti
# 72945    genti
# 72946    genti
# 72947    genti
# Name: l1, Length: 43062, dtype: object

# %%
l1_count = data.groupby("l1").count()["id"].sort_values(ascending=False)[:5]

fig = plt.figure(figsize=[8,5], frameon=False)
ax = fig.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#424242")
ax.spines["bottom"].set_color("#424242")

colors = ["green","blue","magenta","cyan","gray","yellow","purple","violet","orange","red","maroon"]
random.shuffle(colors)
plt.bar(l1_count.index, l1_count.values, color=colors)

plt.xticks(range(0, 6), color="#424242")
plt.yticks(range(0, 25000, 5000), color="#424242")
plt.xlabel("Top 5 l1 types")

for i, v in enumerate(l1_count):
    ax.text(i-0.2, v+500, str(v), color='#424242')
plt.title("Number of properties(by l1 type)")


plt.show()

# %%
data.dtypes
# Out:
# id                  object
# ad_type             object
# start_date          object
# end_date            object
# created_on          object
# lat                float64
# lon                 object
# l1                  object
# l2                  object
# l3                  object
# l4                  object
# l5                  object
# l6                 float64
# rooms              float64
# bedrooms           float64
# bathrooms          float64
# surface_total      float64
# surface_covered    float64
# price              float64
# currency            object
# price_period        object
# title               object
# description         object
# property_type       object
# operation_type      object
# dtype: object

# %%
np.round(data[["price","rooms"]].corr()["price"][1],2)
# Out:
# <ipython-input-94-377c67b1427a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   np.round(data[["price","rooms"]].corr()["price"][1],2)
# np.float64(0.07)

# %%
sns.boxplot(x='price', y='rooms', data=data)
plt.ylim(1)
plt.show()
#Now, it is clear. The higher the price a restaurant charges, more services they provide and hence more chances of getting good ratings from their customers.
